# %% [markdown]
# ## Dataset Description
#
#
# The data set, which is obtained from an Excel file (MIDMARKS.xlsx), consists of student marks in various subjects like Digital Variance (DV), Mathematics-II (M2), Programming Principles (PP), Basic Electrical and Electronics Engineering (BEEE), Formal Languages (FL), and Fundamentals of Information Management Systems (FIMS). There were inconsistencies in the data set in the form of non-numeric data in certain columns, which was made numeric for correct analysis. Missing values were also detected and replaced by 0 to preserve data integrity.
#
# To evaluate overall student performance, a Total column was added by adding marks of all subjects, and a Percentage column was added by calculating total marks into percentage points on a scale of 120 maximum marks. To further classify student performance, a grading system was used to classify students into various grade ranges: A (90%+), B+ (80-89%), B (70-79%), C+ (60-69%), C (50-59%), and D (less than 50%). This system of grading facilitated an understanding of the overall pattern of scores in an organized manner.

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("class_marks.csv")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    NaN    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    NaN    NaN    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    NaN    NaN    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    NaN    NaN    NaN
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    NaN    NaN   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    NaN    NaN    NaN
# 82     27    2.0    2.0    5.0    3.0    NaN    NaN    NaN    NaN    7.0
# 83     37    4.0    6.0    6.0    2.0    NaN    NaN    NaN    NaN    9.0
# 84     28    4.0    NaN    5.0    4.0    5.0    4.0    NaN    NaN    6.0
# 85     29    4.0    6.0    NaN    NaN    NaN    NaN    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     NaN    NaN
# 2     NaN    NaN
# 3     2.0    NaN
# ...

# %% [markdown]
# ## reads the "class_marks.csv"

# %%
df.shape
# Out:
# (86, 12)

# %% [markdown]
# ### gives how many columns and rows

# %%
df=df.fillna(0)

# %%
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37    4.0    5.0    6.0    4.0    2.0    1.0    0.0    5.0    8.0
# 1      32    4.0    3.0    4.0    3.0    0.0    0.0    3.0    6.0    9.0
# 2      33    4.0    5.0    5.0    1.0    5.0    5.0    0.0    0.0    8.0
# 3      24    4.0    6.0    6.0    3.0    2.0    2.0    0.0    0.0    0.0
# 4      36    3.0    6.0    4.0    4.0    5.0    4.0    0.0    0.0   10.0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32    3.0    6.0    3.0    4.0    5.0    3.0    0.0    0.0    0.0
# 82     27    2.0    2.0    5.0    3.0    0.0    0.0    0.0    0.0    7.0
# 83     37    4.0    6.0    6.0    2.0    0.0    0.0    0.0    0.0    9.0
# 84     28    4.0    0.0    5.0    4.0    5.0    4.0    0.0    0.0    6.0
# 85     29    4.0    6.0    0.0    0.0    0.0    0.0    3.0    5.0    7.0
#
#     Q6aM4  Q6bM6
# 0     4.0    6.0
# 1     0.0    0.0
# 2     0.0    0.0
# 3     2.0    0.0
# ...

# %%
df=df.astype("int64")
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6
# 0       4      6
# 1       0      0
# 2       0      0
# 3       2      0
# ...

# %% [markdown]
# ### replaces any missing values  with 0

# %%
DF=df.sort_values("Total",ascending=True)
DF
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 69      3      1      0      1      0      0      0      1      0      0
# 11      8      2      2      0      3      1      0      0      0      0
# 23      9      4      3      0      0      0      0      0      0      0
# 22     14      4      4      5      2      0      0      0      0      0
# 57     17      3      0      0      4      0      0      3      7      0
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73     40      4      6      0      0      5      5      3      0     10
# 53     40      4      6      6      4      5      5      0      0     10
# 51     40      0      0      6      4      0      0      3      7     10
# 33     40      0      0      6      4      5      5      3      7      0
# 65     40      4      6      6      4      5      5      0      0     10
#
#     Q6aM4  Q6bM6
# 69      0      0
# 11      0      0
# 23      1      1
# 22      0      0
# ...

# %% [markdown]
# ### Sorts by Total coloumn in ascending order

# %%
df[df.Total>40].count
df
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6
# 0       4      6
# 1       0      0
# 2       0      0
# 3       2      0
# ...

# %% [markdown]
# ### Filters rows with 'Total' > 40

# %%
df.replace(39,40)
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0      37      4      5      6      4      2      1      0      5      8
# 1      32      4      3      4      3      0      0      3      6      9
# 2      33      4      5      5      1      5      5      0      0      8
# 3      24      4      6      6      3      2      2      0      0      0
# 4      36      3      6      4      4      5      4      0      0     10
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6
# 0       4      6
# 1       0      0
# 2       0      0
# 3       2      0
# ...

# %% [markdown]
# ### Replacing 39 with 40

# %% [markdown]
# ### Filters'Q6'=10,'Total'=20.

# %%
df['Q1']=df["Q1aM4"]+df["Q1bM6"]
df['Q2']=df['Q2aM6']+df['Q2bM4']
df['Q3']=df['Q3aM5']+df['Q3bM5']
df['Q4']=df['Q4aM3']+df['Q4bM7']
df['Q6']=df['Q6aM4']+df['Q6bM6']
columns_to_drop = ["Q1aM4", "Q1bM6", "Q2aM6", "Q2bM4", "Q3aM5", "Q3bM5", "Q4aM3", "Q4bM7", "Q6aM4", "Q6bM6"]
columns_to_drop = [col for col in columns_to_drop if col in df.columns]
df.drop(columns=columns_to_drop)
# Out:
#     Total  Q5M10  Q1  Q2  Q3  Q4  Q6
# 0      37      8   9  10   3   5  10
# 1      32      9   7   7   0   9   0
# 2      33      8   9   6  10   0   0
# 3      24      0  10   9   4   0   2
# 4      36     10   9   8   9   0   0
# ..    ...    ...  ..  ..  ..  ..  ..
# 81     32      0   9   7   8   0  10
# 82     27      7   4   8   0   0   8
# 83     37      9  10   8   0   0  10
# 84     28      6   4   9   9   0   0
# 85     29      7  10   0   0   8   5
#
# [86 rows x 7 columns]

# %% [markdown]
# ### Calculates new columns, drops old ones.

# %%
df.head()
# Out:
#    Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 0     37      4      5      6      4      2      1      0      5      8
# 1     32      4      3      4      3      0      0      3      6      9
# 2     33      4      5      5      1      5      5      0      0      8
# 3     24      4      6      6      3      2      2      0      0      0
# 4     36      3      6      4      4      5      4      0      0     10
#
#    Q6aM4  Q6bM6  Q1  Q2  Q3  Q4  Q6
# 0      4      6   9  10   3   5  10
# 1      0      0   7   7   0   9   0
# 2      0      0   9   6  10   0   0
# 3      2      0  10   9   4   0   2
# 4      0      0   9   8   9   0   0

# %% [markdown]
# ### Gives the List of first 5 values of data

# %%
df.tail()
# Out:
#     Total  Q1aM4  Q1bM6  Q2aM6  Q2bM4  Q3aM5  Q3bM5  Q4aM3  Q4bM7  Q5M10  \
# 81     32      3      6      3      4      5      3      0      0      0
# 82     27      2      2      5      3      0      0      0      0      7
# 83     37      4      6      6      2      0      0      0      0      9
# 84     28      4      0      5      4      5      4      0      0      6
# 85     29      4      6      0      0      0      0      3      5      7
#
#     Q6aM4  Q6bM6  Q1  Q2  Q3  Q4  Q6
# 81      4      6   9   7   8   0  10
# 82      3      5   4   8   0   0   8
# 83      4      6  10   8   0   0  10
# 84      0      0   4   9   9   0   0
# 85      1      4  10   0   0   8   5

# %% [markdown]
# ### Gives the last 5 values of the data

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Total'], bins=10, color='green', edgecolor='black')
plt.title("Distribution of Total Marks", fontsize=14)
plt.xlabel("Total Marks", fontsize=12)
plt.ylabel("Number of Students", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Plots histogram of 'Total' marks

# %%
df.plot()
plt.show()

# %% [markdown]
# ### Plots all DataFrame columns

# %%
df['Q1']=df['Q1aM4']+df["Q1bM6"]
plt.hist(df['Q1'],color='maroon',edgecolor='black',bins=9)
plt.xlabel("Marks scored in Q1")
plt.ylabel("No.of students")
plt.title("Histogram of Q1")
# Out:
# Text(0.5, 1.0, 'Histogram of Q1')

# %% [markdown]
# ### Calculates 'Q1' marks and plots

# %%
df['Q2']=df['Q2aM6']+df["Q2bM4"]
plt.hist(df["Q2"],color='red',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q2")
plt.ylabel("No.of students")
plt.title("Histogram of Q2")
# Out:
# Text(0.5, 1.0, 'Histogram of Q2')

# %% [markdown]
# ### Calculates'Q2'marks and plots histogram

# %%
df['Q3']=df['Q3aM5']+df["Q3bM5"]
plt.hist(df["Q3"],color='yellow',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q3")
plt.ylabel("No.of students")
plt.title("Histogram of Q3")
# Out:
# Text(0.5, 1.0, 'Histogram of Q3')

# %% [markdown]
# ### Calculates 'Q3' marks and plots histogram

# %%
df['Q4']=df['Q4aM3']+df["Q4bM7"]
plt.hist(df["Q4"],color='green',bins=10,edgecolor='black')
plt.xlabel("Marks scored in Q4")
plt.ylabel("No.of students")
plt.title("Histogram of Q4")
# Out:
# Text(0.5, 1.0, 'Histogram of Q4')

# %% [markdown]
# ### Calculates 'Q4' marks and plots histogram.

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Total'}>,
#         <Axes: title={'center': 'Q1aM4'}>,
#         <Axes: title={'center': 'Q1bM6'}>,
#         <Axes: title={'center': 'Q2aM6'}>],
#        [<Axes: title={'center': 'Q2bM4'}>,
#         <Axes: title={'center': 'Q3aM5'}>,
#         <Axes: title={'center': 'Q3bM5'}>,
#         <Axes: title={'center': 'Q4aM3'}>],
#        [<Axes: title={'center': 'Q4bM7'}>,
#         <Axes: title={'center': 'Q5M10'}>,
#         <Axes: title={'center': 'Q6aM4'}>,
#         <Axes: title={'center': 'Q6bM6'}>],
#        [<Axes: title={'center': 'Q1'}>, <Axes: title={'center': 'Q2'}>,
#         <Axes: title={'center': 'Q3'}>, <Axes: title={'center': 'Q4'}>],
#        [<Axes: title={'center': 'Q6'}>, <Axes: >, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# ### Plots histograms for all columns

# %%
df.plot.scatter(x = 'Q1', y = 'Total',color='green',s=60)
plt.title("Scatter Plot for Q1")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q1')

# %% [markdown]
# ### Majority of the students got 10 marks maximum

# %%
df.plot.scatter(x = 'Q5M10', y = 'Total',color='red',s=50)
plt.title("Scatter Plot for Q5M10")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q5M10')

# %% [markdown]
# ### scatterplot for 'Q5M10' vs 'Total'

# %%
df.plot.scatter(x = 'Q2', y = 'Total',color='blue',s=30)
plt.title("Scatter Plot for Q2")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q2')

# %%
df.plot.scatter(x = 'Q4', y = 'Total',color='yellow',s=30)
plt.title("Scatter Plot for Q4")
# Out:
# Text(0.5, 1.0, 'Scatter Plot for Q4')

# %% [markdown]
# ### scatterplot for 'Q4' vs 'Total'

# %%
df.hist("Total")
# Out:
# array([[<Axes: title={'center': 'Total'}>]], dtype=object)

# %% [markdown]
# ### Plots histogram for 'Total

# %%
df.boxplot(by='Q1', column =['Total'], grid = False,color='Yellow',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# ### Plots boxplot of 'Total' by 'Q1'

# %%
df.boxplot(by='Q2', column =['Total'], grid = False,color='green')
plt.title("Boxplot of Q2")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# ### Plots boxplot of 'Total' by 'Q2'

# %%
df.boxplot(by='Q3', column =['Total'], grid = False,color='orange')
plt.title("Boxplot of Q3")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# ### Plots boxplot of 'Total' by 'Q3'

# %%
df.boxplot(by='Q4',column =['Total'], grid = False,color='blue',figsize=[5,6])
plt.title("25-30 Marks")
plt.ylabel("Total")
plt.show()

# %% [markdown]
# ### Plots boxplot of 'Total' by 'Q4'

# %%
n = pd.read_csv("class_marks.csv", skiprows=70)
explode_values = [0.1] * len(n['1.1'])  

n['1.1'].plot(kind='pie', figsize=(8, 10), explode=explode_values, autopct='%1.1f%%')  # Added explode and autopct
plt.title("Piechart of marks in Q5")
plt.show()

# %% [markdown]
# ###  plots pie chart with explode effect

# %% [markdown]
# ### Plots pie chart of 'Q1'

# %%
df=pd.read_csv("class_marks.csv",skiprows=70)
df
df['1.1'].plot(kind='pie',figsize=(8,10))
plt.title("Piechart of marks in Q5M10")
# Out:
# Text(0.5, 1.0, 'Piechart of marks in Q5M10')

# %% [markdown]
# ### Pie chart of Q5M10

# %% [markdown]
# ## Dataset Observation
#
#
#
# After cleaning and organizing the dataset, different statistical and graphical analyses were performed to get deeper insights. Histograms and distribution plots were created using Seaborn and Matplotlib to understand the distribution of student marks over different subjects. Total marks distribution gave a clear indication of how students performed overall, whereas the percentage distribution indicated if most of the students were concentrated in a particular range or there was a high variation in scores. Further, a grade-wise distribution analysis was done to see the number of students in each grade category to understand overall trends of performance.
#
# Aside from individual marks analysis, a correlation study was performed to analyze the relationship between various subjects. This assisted in the identification of those subjects that correlated well with each other, such that students who excelled in one subject tended to excel in another. This information could prove beneficial in terms of determining if there are particular subjects that need more focus or if there is a pattern to student strengths.
#
# Overall, the dataset was reformed from raw, inconsistent records into a properly structured, insightful dataset that offered a clear view of student performance, grading distributions, and subject-wise analysis. The study not only identified score distributions and trends but also gave valuable insights into areas of potential academic improvement.
